# %%
import os
import re
from typing import List
import joblib
import logging
from pyspark.sql import SparkSession, DataFrame
from pyspark.sql.types import StructType, StructField, StringType, IntegerType
import pandas as pd


from object_types import CAREER_FRAME, DRAFT, WIKI_PLAYER

MERGED_DIR = './players_merged'

logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s - %(levelname)s - %(message)s'
)
logger = logging.getLogger(__name__)

spark = SparkSession.builder \
    .master("local[*]") \
    .appName("Parse data") \
    .config("spark.driver.host", "0.0.0.0") \
    .config("spark.executor.memory", "4g") \
    .config("spark.driver.memory", "4g") \
    .config("spark.executor.memoryOverhead", "2g") \
    .config("spark.executor.cores", "2") \
    .config("spark.dynamicAllocation.enabled", "false") \
    .config("spark.shuffle.service.enabled", "false") \
    .config("spark.driver.maxResultSize", "2g") \
    .config("spark.driver.maxResultSize", "4g") \
    .config("spark.sql.execution.pythonUTF8StringEncoding", "true") \
    .getOrCreate()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# 25/11/23 16:33:03 WARN Utils: Your hostname, MacBook-Air-uzivatela-Jaroslava.local, resolves to a loopback address: 127.0.0.1; using 192.168.100.56 instead (on interface en0)
# 25/11/23 16:33:03 WARN Utils: Set SPARK_LOCAL_IP if you need to bind to another address
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 25/11/23 16:33:04 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable

# %%
def load_df(file_path = './processed_pages.joblib') -> DataFrame:
    pd_df: pd.DataFrame = joblib.load(file_path)
    return spark.createDataFrame(pd_df)

wiki_df = load_df('./wiki_df.joblib')
html_df = load_df('./html_df.joblib')
merged_df = load_df('./merged_df.joblib')

# %%
html_df.describe()
# Out:
# DataFrame[summary: string, file_path: string, download_url: string, player_name: string, dob: string, draft_team: string, position: string, hand: string, height: string, weight: string, games_played: string, wins: string, losses: string, ties_ot_losses: string, minutes: string, shootouts: string, gaa: string, save_percentage: string, goals: string, assists: string, points: string, plus_minus: string, point_shares: string, penalty_minutes: string, shots_on_goal: string, game_winning_goals: string]

# %%
wiki_df.describe()
# Out:
# DataFrame[summary: string, full_name: string, birthplace: string, career_start: string, career_end: string, draft: string, draft_year: string, draft_team: string, current_league: string, national_team: string, current_team: string, nationality: string]

# %%
html_df.count()
# Out:
# 12165

# %%
wiki_df.count()
# Out:
# 19722

# %%
merged_df = html_df.join(wiki_df, wiki_df['full_name'] == html_df['player_name'], how="left")

# %%
merged_df.show(n=5)
# Out:
# +--------------------+--------------------+------------------+-----------------+----------+----------+----+------+------+------------+----+------+--------------+-------+---------+---+---------------+-----+-------+------+----------+-------------------+---------------+-------------+------------------+--------------+----------------+------------+----------+-------------+----------+--------------------+--------------------+-------------+------------------+-----------+
# |           file_path|        download_url|       player_name|              dob|draft_team|  position|hand|height|weight|games_played|wins|losses|ties_ot_losses|minutes|shootouts|gaa|save_percentage|goals|assists|points|plus_minus|       point_shares|penalty_minutes|shots_on_goal|game_winning_goals|     full_name|      birthplace|career_start|career_end|        draft|draft_year|          draft_team|      current_league|national_team|      current_team|nationality|
# +--------------------+--------------------+------------------+-----------------+----------+----------+----+------+------+------------+----+------+--------------+-------+---------+---+---------------+-----+-------+------+----------+-------------------+---------------+-------------+------------------+--------------+----------------+------------+----------+-------------+----------+--------------------+--------------------+-------------+------------------+-----------+
# |.\scraped\players...|https://www.hocke...|       Antti Aalto|    March 4, 1975|         C|   Anaheim|Left| 185.0|  95.0|       151.0| NaN|   NaN|           NaN|    NaN|      NaN|NaN|            NaN| 11.0|   17.0|  28.0|     -25.0| 0.4000000059604645|           52.0|        182.0|               1.0|          NULL|            NULL|        NULL|      NULL|         NULL|      NULL|                NULL|                NULL|         NULL|              NULL|       NULL|
# |.\scraped\players...|https://www.hocke...|       Bruce Abbey|  August 18, 1951|         D|      NULL|Left| 185.0|  83.0|         NaN| NaN|   NaN|           NaN|    NaN|      NaN|NaN|            NaN|  NaN|    NaN|   NaN|       NaN|                NaN|            NaN|          NaN|               NaN|   Bruce Abbey| , Central Elgin|      1975.0|    1981.0| 91st overall|      1971|Minnesota North S...|                NULL|         NULL|              NULL|       NULL|
# |.\scraped\players...|https://www.hocke...|      Wyatt Aamodt|November 22, 1997|         D|      NULL|Left| 183.0|  91.0|         2.0| NaN|   NaN|           NaN|    NaN|      NaN|NaN|            NaN|  1.0|    0.0|   1.0|       1.0|0.30000001192092896|            0.0|          3.0|               0.0|  Wyatt Aamodt|     , Minnesota|      2022.0|       NaN|    Undrafted|      NULL|                NULL|National Hockey L...|         NULL|Colorado Avalanche|   American|
# |.\scraped\players...|https://www.hocke...|Juhamatti Aaltonen|     June 4, 1985|        RW| St. Louis|NULL|   NaN|   NaN|         NaN| NaN|   NaN|           NaN|    NaN|      NaN|NaN|            NaN|  NaN|    NaN|   NaN|       NaN|                NaN|            NaN|          NaN|               NaN|          NULL|            NULL|        NULL|      NULL|         NULL|      NULL|                NULL|                NULL|         NULL|              NULL|       NULL|
# |.\scraped\players...|https://www.hocke...|    Leevi Aaltonen| January 24, 2001|        RW|NY Rangers|Left| 173.0|  80.0|         NaN| NaN|   NaN|           NaN|    NaN|      NaN|NaN|            NaN|  NaN|    NaN|   NaN|       NaN|                NaN|            NaN|          NaN|               NaN|Leevi Aaltonen|Mikkeli, Finland|      2019.0|       NaN|130th overall|      2019|    New York Rangers|               Liiga|         NULL|    KooKoo (Liiga)|    Finnish|
# +--------------------+--------------------+------------------+-----------------+----------+----------+----+------+------+------------+----+------+--------------+-------+---------+---+---------------+-----+-------+------+----------+-------------------+---------------+-------------+------------------+--------------+----------------+------------+----------+-------------+----------+--------------------+--------------------+-------------+------------------+-----------+
# only showing top 5 rows

# %%
wiki_df = wiki_df.drop('draft_team')

# %%
merged_df.count()
# Out:
# 12197

# %%
def dump_df(df: DataFrame, file_path = './processed_pages.joblib'):
    pd_df = df.toPandas()
    joblib.dump(pd_df, file_path)

dump_df(merged_df, './left_merged.joblib')

# %%
merged_df.describe()
# Out:
# DataFrame[summary: string, file_path: string, download_url: string, player_name: string, dob: string, position: string, hand: string, height: string, weight: string, games_played: string, wins: string, losses: string, ties_ot_losses: string, minutes: string, shootouts: string, gaa: string, save_percentage: string, goals: string, assists: string, points: string, plus_minus: string, point_shares: string, penalty_minutes: string, shots_on_goal: string, game_winning_goals: string, full_name: string, birthplace: string, career_start: string, career_end: string, draft: string, draft_year: string, draft_team: string, current_league: string, national_team: string, current_team: string, nationality: string]

# %%
html_df.show(n=2)
# Out:
# [Stage 0:>                                                          (0 + 1) / 1]
# +--------------------+--------------------+------------------+-------------+--------+----------+----+------+------+------------+----+------+--------------+-------+---------+---+---------------+-----+-------+------+----------+------------------+---------------+-------------+------------------+
# |           file_path|        download_url|       player_name|          dob|position|draft_team|hand|height|weight|games_played|wins|losses|ties_ot_losses|minutes|shootouts|gaa|save_percentage|goals|assists|points|plus_minus|      point_shares|penalty_minutes|shots_on_goal|game_winning_goals|
# +--------------------+--------------------+------------------+-------------+--------+----------+----+------+------+------------+----+------+--------------+-------+---------+---+---------------+-----+-------+------+----------+------------------+---------------+-------------+------------------+
# |.\scraped\players...|https://www.hocke...|       Antti Aalto|March 4, 1975|       C|   Anaheim|Left| 185.0|  95.0|       151.0| NaN|   NaN|           NaN|    NaN|      NaN|NaN|            NaN| 11.0|   17.0|  28.0|     -25.0|0.4000000059604645|           52.0|        182.0|               1.0|
# |.\scraped\players...|https://www.hocke...|Juhamatti Aaltonen| June 4, 1985|      RW| St. Louis|NULL|   NaN|   NaN|         NaN| NaN|   NaN|           NaN|    NaN|      NaN|NaN|            NaN|  NaN|    NaN|   NaN|       NaN|               NaN|            NaN|          NaN|               NaN|
# +--------------------+--------------------+------------------+-------------+--------+----------+----+------+------+------------+----+------+--------------+-------+---------+---+---------------+-----+-------+------+----------+------------------+---------------+-------------+------------------+
# only showing top 2 rows

# %%
direct_df = load_df('./direct_df.joblib')

# %%
html_df = direct_df

# %%
temp_view_name = "players"
merged_df.createOrReplaceTempView(temp_view_name)

spark.sql(f"select * from {temp_view_name} where player_name is not null and full_name is not null limit 5").show()
# Out:
# 25/11/13 12:13:58 WARN SparkStringUtils: Truncated the string representation of a plan since it was too large. This behavior can be adjusted by setting 'spark.sql.debug.maxToStringFields'.
# +--------------------+--------------------+--------------------+------------------+----------+---------+-----+------+------+------------+-----+------+--------------+-------+---------+---+---------------+-----+-------+------+----------+-------------------+---------------+-------------+------------------+--------------------+--------------------+------------+----------+--------------------+----------+--------------------+--------------------+-------------+-------------------+-----------+
# |           file_path|        download_url|         player_name|               dob|draft_team| position| hand|height|weight|games_played| wins|losses|ties_ot_losses|minutes|shootouts|gaa|save_percentage|goals|assists|points|plus_minus|       point_shares|penalty_minutes|shots_on_goal|game_winning_goals|           full_name|          birthplace|career_start|career_end|               draft|draft_year|          draft_team|      current_league|national_team|       current_team|nationality|
# +--------------------+--------------------+--------------------+------------------+----------+---------+-----+------+------+------------+-----+------+--------------+-------+---------+---+---------------+-----+-------+------+----------+-------------------+---------------+-------------+------------------+--------------------+--------------------+------------+----------+--------------------+----------+--------------------+--------------------+-------------+-------------------+-----------+
# |.\scraped\players...|https://www.hocke...|David John Andrey...|September 29, 1963|        LW|  Buffalo|Right| 193.0|  99.0|      1639.0|  NaN|   NaN|           NaN|    NaN|      NaN|NaN|            NaN|640.0|  698.0|1338.0|      32.0|  124.4000015258789|         1121.0|       4556.0|              77.0|David John Andrey...|Hamilton, Ontario...|      1982.0|    2006.0|        16th overall|      1982|      Buffalo Sabres|                NULL|          CAN|               NULL|       NULL|
# |.\scraped\players...|https://www.hocke...|       Justin Bailey|      July 1, 1995|        RW|  Buffalo|Right| 193.0|  97.0|       141.0|  NaN|   NaN|           NaN|    NaN|      NaN|NaN|            NaN| 10.0|   13.0|  23.0|     -26.0|0.30000001192092896|           24.0|        175.0|               1.0|       Justin Bailey|Buffalo, New York...|      2015.0|       NaN|        52nd overall|      2013|      Buffalo Sabres|American Hockey L...|         NULL|    San Diego Gulls|   American|
# |.\scraped\players...|https://www.hocke...|Christopher Alfre...|     July 31, 1952|         D|Minnesota|Right| 183.0|  83.0|        52.0|  NaN|   NaN|           NaN|    NaN|      NaN|NaN|            NaN|  0.0|    3.0|   3.0|     -26.0|                0.5|           84.0|         26.0|               0.0|Christopher Alfre...|San Bernardino, U.S.|      1972.0|    1978.0|        76th overall|      1972|Minnesota North S...|                NULL|         NULL|               NULL|   American|
# |.\scraped\players...|https://www.hocke...|   Frederik Andersen|   October 2, 1989|         G| Carolina| Left| 193.0| 103.0|       518.0|309.0| 135.0|          53.0|29946.0|      NaN|NaN|           28.0|  NaN|    NaN|   NaN|       NaN|                NaN|            NaN|          NaN|               NaN|   Frederik Andersen|Herning, Denmark&...|      2008.0|       NaN|187th overall, [[...|      2012|       Anaheim Ducks|National Hockey L...|          DNK|Carolina Hurricanes|     Danish|
# |.\scraped\players...|https://www.hocke...|        Pierre Aubry|    April 15, 1960|        LW|     NULL| Left| 178.0|  77.0|       201.0|  NaN|   NaN|           NaN|    NaN|      NaN|NaN|            NaN| 24.0|   26.0|  50.0|     -21.0| -1.399999976158142|          133.0|        168.0|               2.0|        Pierre Aubry|Cap-de-la-Madelei...|      1980.0|    1991.0|           Undrafted|      NULL|                NULL|                NULL|         NULL|               NULL|   Canadian|
# +--------------------+--------------------+--------------------+------------------+----------+---------+-----+------+------+------------+-----+------+--------------+-------+---------+---+---------------+-----+-------+------+----------+-------------------+---------------+-------------+------------------+--------------------+--------------------+------------+----------+--------------------+----------+--------------------+--------------------+-------------+-------------------+-----------+

# %%
spark.sql(f"select count(distinct player_name, full_name) from {temp_view_name}").show()
# Out:
# [Stage 30:=====================>                                    (3 + 5) / 8]
# +--------------------------------------+
# |count(DISTINCT player_name, full_name)|
# +--------------------------------------+
# |                                  4854|
# +--------------------------------------+

# %%
html_view = "html"
html_df.createOrReplaceTempView(html_view)

spark.sql(f"""
    SELECT COUNT(player_name) as count_name, player_name 
    FROM {html_view} 
    WHERE player_name IS NOT NULL 
    GROUP BY player_name
    HAVING COUNT(player_name) > 1
""").show()
# Out:
# [Stage 0:>                                                          (0 + 8) / 8]
# +----------+--------------------+
# |count_name|         player_name|
# +----------+--------------------+
# |         7|                 JiÅ|
# |         2|               ZdenÄ|
# |         3|               AndrÃ|
# |         4|                  SÃ|
# |         2|   Sylvanus Marshall|
# |         2|       Josh Anderson|
# |         2|       Sebastian Aho|
# |         4|                 FrÃ|
# |         4|          Jean-FranÃ|
# |         2|  John Matthew Adams|
# |         4|          Marc-AndrÃ|
# |         2| Michael John Boland|
# |         2|           Harvey A.|
# |         4|                   Ã|
# |         2|Ronald Henry Ande...|
# |         3|             Jean-SÃ|
# |         2| Gregory Daren Adams|
# |         3|     Peter Andersson|
# |         2|Garnet Edward Bailey|
# |         2|             Roman Ä|
# +----------+--------------------+
# only showing top 20 rows

# %%
merged_view = "merged"
merged_df.createOrReplaceTempView(merged_view)

# %%
spark.sql(f"""
    select download_url, player_name, dob
    from {merged_view}
    where player_name is not null and full_name is null
""").show(truncate=False, n=200)
# Out:
# [Stage 112:>                (0 + 8) / 8][Stage 114:>                (0 + 0) / 1]
# +---------------------------------------------------------+-------------------------------+------------------+
# |download_url                                             |player_name                    |dob               |
# +---------------------------------------------------------+-------------------------------+------------------+
# |https://www.hockey-reference.com/players/g/greeraj01.html|A                              |December 14, 1996 |
# |https://www.hockey-reference.com/players/r/rasanaa01.html|Aapeli Rasanen                 |June 1, 1998      |
# |https://www.hockey-reference.com/players/t/talviaa01.html|Aarne Talvitie                 |February 11, 1999 |
# |https://www.hockey-reference.com/players/b/broteaa01.html|Aaron Broten                   |November 14, 1960 |
# |https://www.hockey-reference.com/players/d/dawsoaa01.html|Aaron Dawson                   |March 11, 1985    |
# |https://www.hockey-reference.com/players/h/harstaa01.html|Aaron Harstad                  |April 27, 1992    |
# |https://www.hockey-reference.com/players/h/haydoaa01.html|Aaron Haydon                   |January 6, 1996   |
# |https://www.hockey-reference.com/players/h/hugleaa01.html|Aaron Huglen                   |March 6, 2001     |
# |https://www.hockey-reference.com/players/i/irvinaa01.html|Aaron Irving                   |March 3, 1996     |
# |https://www.hockey-reference.com/players/j/johnsaa01.html|Aaron Johnson                  |April 30, 1983    |
# |https://www.hockey-reference.com/players/l/lobbaa01.html |Aaron Lobb                     |June 10, 1983     |
# |https://www.hockey-reference.com/players/m/mackeaa01.html|Aaron MacKenzie                |March 7, 1981     |
# |https://www.hockey-reference.com/players/m/marviaa01.html|Aaron Marvin                   |May 27, 1988      |
# |https://www.hockey-reference.com/players/n/nessaa01.html |Aaron Ness                     |May 18, 1990      |
# |https://www.hockey-reference.com/players/p/palusaa01.html|Aaron Palushaj                 |September 7, 1989 |
# |https://www.hockey-reference.com/players/p/pionkaa01.html|Aaron Pionk                    |January 16, 2003  |
# |https://www.hockey-reference.com/players/s/snowaa01.html |Aaron Snow                     |May 20, 1988      |
# |https://www.hockey-reference.com/players/v/volpaaa01.html|Aaron Volpatti                 |May 30, 1985      |
# |https://www.hockey-reference.com/players/j/jamseaa01.html|Aatu Jamsen                    |July 22, 2002     |
# |https://www.hockey-reference.com/players/k/kadeyal01.html|Alexander Kadeykin             |October 4, 1993   |
# |https://www.hockey-reference.com/players/k/kaletal01.html|Alexander Kaleta               |November 29, 1919 |
# |https://www.hockey-reference.com/players/k/karpoal01.html|Alexander Karpovtsev           |April 7, 1970     |
# |https://www.hockey-reference.com/players/k/kerchal01.html|Alexander Kerch                |March 16, 1967    |
# |https://www.hockey-reference.com/players/k/kerfoal01.html|Alexander Kerfoot              |August 11, 1994   |
# |https://www.hockey-reference.com/players/k/kharial01.html|Alexander Kharitonov           |March 30, 1976    |
# |https://www.hockey-reference.com/players/k/khavaal01.html|Alexander Khavanov             |January 30, 1972  |
# |https://www.hockey-reference.com/players/k/khokhal01.html|Alexander Khokhlachev          |September 9, 1993 |
# |https://www.hockey-reference.com/players/k/khovaal01.html|Alexander Khovanov             |April 12, 2000    |
# |https://www.hockey-reference.com/players/k/kojeval01.html|Alexander Kojevnikov           |April 12, 1984    |
# |https://www.hockey-reference.com/players/c/cookbu02.html |Alexander Leone Lally Cook     |November 20, 1907 |
# |https://www.hockey-reference.com/players/l/ljungal01.html|Alexander Ljungkrantz          |February 27, 2002 |
# |https://www.hockey-reference.com/players/t/tideyal01.html|Alexander Mansfield Tidey      |January 5, 1955   |
# |https://www.hockey-reference.com/players/m/mccarsa01.html|Alexander McCarthy             |June 15, 1972     |
# |https://www.hockey-reference.com/players/m/mckenal01.html|Alexander McKendry             |November 21, 1956 |
# |https://www.hockey-reference.com/players/m/mikhaal01.html|Alexander Mikhailishin         |February 24, 1986 |
# |https://www.hockey-reference.com/players/o/ovechal01.html|Alexander Mikhaylovich Ovechkin|September 17, 1985|
# |https://www.hockey-reference.com/players/n/nauroal01.html|Alexander Naurov               |March 4, 1985     |
# |https://www.hockey-reference.com/players/n/nikisal01.html|Alexander Nikishin             |October 2, 2001   |
# |https://www.hockey-reference.com/players/n/nikulal01.html|Alexander Nikulin              |August 25, 1985   |
# |https://www.hockey-reference.com/players/n/nylanal01.html|Alexander Nylander             |March 2, 1998     |
# |https://www.hockey-reference.com/players/p/pashial01.html|Alexander Pashin               |July 28, 2002     |
# |https://www.hockey-reference.com/players/p/pechual01.html|Alexander Pechurski            |June 4, 1990      |
# |https://www.hockey-reference.com/players/p/peleval01.html|Alexander Pelevin              |May 16, 2004      |
# |https://www.hockey-reference.com/players/p/pereval01.html|Alexander Perevalov            |April 16, 2004    |
# +---------------------------------------------------------+-------------------------------+------------------+
# only showing top 200 rows

# %%
data = joblib.load('./processed_data.joblib')

# %%
def load_from_tsv() -> DataFrame:
    df = spark.read \
    .option("header", "true") \
    .option("delimiter", "\t") \
    .option("nullValue", None) \
    .option("emptyValue", None) \
    .schema(WIKI_PLAYER_SCHEMA) \
    .csv(os.path.join('.', 'wiki_df', 'data.tsv'))
    return df 

wiki_df = load_from_tsv()

# %%
wiki_df.count()
# Out:
# 19731
